# %%
# 1️⃣ Importando bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Melhor visualização dos gráficos
plt.style.use("seaborn-v0_8")

# 2️⃣ Dados de exemplo (substitua pelos seus dados oficiais)
dados = {
    "year": [2018, 2019, 2020, 2021, 2022]*2,
    "type": ["Onshore"]*5 + ["Offshore"]*5,
    "capacity_factor": [28, 30, 29, 31, 32, 40, 42, 41, 43, 44],
    "cost_per_mwh": [60, 58, 57, 56, 55, 90, 88, 87, 85, 84]
}

df = pd.DataFrame(dados)

# 3️⃣ Boxplot: Comparação do fator de capacidade
plt.figure(figsize=(8,5))
sns.boxplot(data=df, x="type", y="capacity_factor", palette="Set2")
plt.title("Capacity Factor Comparison: Onshore vs Offshore")
plt.ylabel("Capacity Factor (%)")
plt.show()

# 4️⃣ Gráfico de linha: Evolução do custo por MWh ao longo dos anos
plt.figure(figsize=(10,6))
sns.lineplot(data=df, x="year", y="cost_per_mwh", hue="type", marker="o")
plt.title("Cost Evolution of Wind Energy in the Netherlands")
plt.ylabel("Cost per MWh (€)")
plt.show()

# 5️⃣ Tabela de resumo estatístico
summary = df.groupby("type")[["capacity_factor", "cost_per_mwh"]].describe()
display(summary)

# 6️⃣ Exportar resumo para CSV (opcional)
summary.to_csv("wind_energy_summary.csv")
# Out:
# /tmp/ipython-input-4158460503.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="type", y="capacity_factor", palette="Set2")
#          capacity_factor                                                \
#                    count  mean       std   min   25%   50%   75%   max
# type
# Offshore             5.0  42.0  1.581139  40.0  41.0  42.0  43.0  44.0
# Onshore              5.0  30.0  1.581139  28.0  29.0  30.0  31.0  32.0
#
#          cost_per_mwh
#                 count  mean       std   min   25%   50%   75%   max
# type
# Offshore          5.0  86.8  2.387467  84.0  85.0  87.0  88.0  90.0
# Onshore           5.0  57.2  1.923538  55.0  56.0  57.0  58.0  60.0
